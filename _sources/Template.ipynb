# %% [markdown]
# # Template Page

# %% [markdown]
# This is a template Book page you can directly edit for your own purposes. Start by renaming this page in the top tab and changing the page title in the cell above. Remember to update the `_toc.yml` file respectively with the new file name.

# %% [markdown]
# ## 1 First Subject

# %% [markdown]
# Here you elaborate about the first subject and visualize it with a code cell:

# %%
### python example to visualize the subject
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 5, 100)
y = np.exp(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('exp(x)')
plt.title('Exponential Function')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2 Second Subject

# %% [markdown]
# Here is a table to present the second subject

# %% [markdown]
# | col 1 | col2 |
# | :-| -:|
# | x1 | x3 |
# | x2 | x4 |

# %% [markdown]
# ## 3 Third Subject

# %% [markdown]
# This third subject will contain an image:
#
# ```{figure} ./tau_logo.jpg
# :height: 100px
# :name: label
#
# Here is my image!
# ```
